# %%
import pandas as pd
import numpy as np
import os

# %%
folder_to_read = '../data/raw/'
folder_to_write = '../data/V1/'

# %% [markdown]
# ### Comumunes

# %%
file_to_read = 'communes.xlsx'
file_to_write = 'communes.csv'
df = pd.read_excel(os.path.join(folder_to_read, file_to_read))
df.to_csv(os.path.join(folder_to_write, file_to_write), index=False, encoding='utf-8')
del file_to_read, file_to_write, df

# %% [markdown]
# ### Districts

# %%
file_to_read = 'districts.xlsx'
file_to_write = 'districts.csv'
df = pd.read_excel(os.path.join(folder_to_read, file_to_read))
df.to_csv(os.path.join(folder_to_write, file_to_write), index=False, encoding='utf-8')
del file_to_read, file_to_write, df

# %% [markdown]
# ### Provinces

# %%
file_to_read = 'provinces.xlsx'
file_to_write = 'provinces.csv'
df = pd.read_excel(os.path.join(folder_to_read, file_to_read))
df.to_csv(os.path.join(folder_to_write, file_to_write), index=False, encoding='utf-8')
del file_to_read, file_to_write, df

# %% [markdown]
# ### Precipitation data
